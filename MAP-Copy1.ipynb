# %%
import folium

# %%
import pandas as pd

# %%
marker1 = pd.read_csv('map2.csv')

# %%
marker1.head()
# Out:
#                  name   latitude  longitude  rating   type colour  \
# 0        Silversands   56.978912  -5.844641       5  STOP    blue
# 1         Leadhillls   55.429969  -3.763853       5  STOP    blue
# 2  St Columba's Cave   55.935970  -5.591842       5  STOP    blue
# 3       Bealach na Ba  57.411593  -5.700804       4  STOP    blue
# 4       Beaver Trail   56.060700  -5.553366       3   POI   pink
#
#                                          description
# 0                         white beach, clear waters
# 1       quiet place, gold paning, good birdwatching
# 2        sea otters, cool cave, quiet, birdwatching
# 3  viewpoint to islands, good parking, windy as f...
# 4      nice walk with chance to sea scottish beavers

# %%
labels=df['marker1'].iloc[i] #Create a lable that is the name of the institution

# %%
marker1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 7 columns):
# name           38 non-null object
# latitude       38 non-null float64
# longitude      38 non-null float64
# rating         38 non-null int64
# type           38 non-null object
# colour         38 non-null object
# description    38 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.2+ KB

# %%
my_maps = folium.Map(
)

for _,place in marker1.iterrows():
    folium.Marker(
        location=[place['latitude'], place['longitude']],
        popup=place[['name', 'description']],
        icon=folium.Icon(color=place['colour'])
    ).add_to(my_maps)
    
    
my_maps
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: color argument of Icon should be one of: {'lightred', 'cadetblue', 'white', 'black', 'beige', 'darkred', 'lightgreen', 'pink', 'gray', 'darkpurple', 'lightblue', 'purple', 'darkgreen', 'blue', 'darkblue', 'red', 'lightgray', 'green', 'orange'}.
# ...

# %%
my_maps.save('my_maps.html')

# %%
icon=folium.Icon(color=place['colour'])

# %%
marker1['latitude'] = marker1['latitude'].astype(int)
marker1['longitude'] = marker1['longitude'].astype(int)
